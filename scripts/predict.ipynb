# %% [markdown]
# # This notebook for preprocessing and deep-learning model model implemented using pytorch of the Devices-Price-Classification-System project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## importing libraries

# %%
def return_predictedPrice():
       # importing the libraries
       import os
       import sys
       import pandas as pd
       import joblib
       project_path = os.path.abspath(os.path.join("." ,".."))
       # load the model
       LogisticRegressionModel = joblib.load(f'{project_path}/data/savings/LogisticRegressionModel.joblib')
       columns_names = ['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
                       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
                       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
                       'touch_screen', 'wifi']
       #device_to_predict_price = pd.DataFrame(columns=columns_names)
       #device_to_predict_price.loc[-1] = sys.argv
       device_to_predict_price = pd.Series({name: val for name, val in zip(columns_names, sys.argv)})
       # run model prediction
       predictedPrice = LogisticRegressionModel.predict(device_to_predict_price)
       # return the prediction
       return predictedPrice

return_predictedPrice()
#names = Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'touch_screen', 'wifi', 'price_range'])
# Out:
# c:\Users\All\Documents\GitHub\Devices-Price-Classification-System
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\All\miniconda3\envs\venv\Lib\site-packages\sklearn\base.py:420, in BaseEstimator._check_n_features(self, X, reset)
#     419 try:
# --> 420     n_features = _num_features(X)
#     421 except TypeError as e:
#
# File c:\Users\All\miniconda3\envs\venv\Lib\site-packages\sklearn\utils\validation.py:345, in _num_features(X)
#     344     message += f" with shape {X.shape}"
# --> 345     raise TypeError(message)
#     346 return X.shape[1]
#
# TypeError: Unable to find the number of features from X of type pandas.core.series.Series with shape (2,)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 19
# ...

# %%
# %cd "c:\Users\All\Documents\GitHub"


project_path = os.path.abspath(os.path.join("." ,"../.."))
print(project_path)
# !dir
# Out:
# c:\Users\All\Documents\GitHub
# c:\Users\All
# c:\Users\All\miniconda3\envs\venv\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#  Volume in drive C has no label.
#  Volume Serial Number is DC7B-D503
#
#  Directory of c:\Users\All\Documents\GitHub
#
# 05/17/2024  02:32 PM    <DIR>          .
# 05/17/2024  02:32 PM    <DIR>          ..
# 06/03/2024  01:51 PM    <DIR>          Devices-Price-Classification-System
#                0 File(s)              0 bytes
#                3 Dir(s)  96,170,909,696 bytes free

# %%
columns_names = ['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']
xtest = [0, 1, 2, 1, 0, 1, 1, 1, 1, 1, 0, 1, 2, 1, 0, 1, 1, 1, 1, 1 ]
device_to_predict_price = pd.Series({name: val for name, val in zip(columns_names, xtest)})
device_to_predict_price
# Out:
# battery_power    0
# blue             1
# clock_speed      2
# dual_sim         1
# fc               0
# four_g           1
# int_memory       1
# m_dep            1
# mobile_wt        1
# n_cores          1
# pc               0
# px_height        1
# px_width         2
# ram              1
# sc_h             0
# sc_w             1
# talk_time        1
# three_g          1
# touch_screen     1
# wifi             1
# dtype: int64

# %%
# Out:
# 'c:\\Users\\All\\Documents\\GitHub\\Devices-Price-Classification-System'
